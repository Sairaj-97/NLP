# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairaj-97/NLP/blob/main/bag_of_words(CountVectorizer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align='center'>NLP Tutorial: Text Representation - Bag Of Words (BOW)</h2>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['Category'].value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
def process(inp):
  if inp=='spam':
    return 1
  else:
    return 0

df['spam']=df['Category'].apply(process)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# <h3>Train test split</h3>

# %%
X=df['Message']
y=df['spam']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %% [markdown]
# <h3>Create bag of words representation using CountVectorizer</h3>

# %% [markdown]
# <h3>Train the naive bayes model</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer()
# Fit the vectorizer on training data and transform it
X_train_cv = v.fit_transform(X_train.values)
# Transform the test data using the same vectorizer (do NOT fit again)
X_test_cv = v.transform(X_test.values)

# Train the Naive Bayes model
model = MultinomialNB()
model.fit(X_train_cv, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_cv)

# %% [markdown]
# <h3>Evaluate Performance</h3>

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9820627802690582

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.98      1.00      0.99       958\n           1       0.98      0.89      0.93       157\n\n    accuracy                           0.98      1115\n   macro avg       0.98      0.94      0.96      1115\nweighted avg       0.98      0.98      0.98      1115\n'

# %% [markdown]
# <h3>Train the model using sklearn pipeline and reduce number of lines of code</h3>

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       958
#            1       0.98      0.89      0.93       157
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
